# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

import json
import os

# Define the base URL and list of generations to scrape
base_url = 'https://www.wikidex.net/wiki/'
gens = ['Lista_de_Pokémon_de_la_primera_generación',
        'Lista_de_Pokémon_de_la_segunda_generación',
        'Lista_de_Pokémon_de_la_tercera_generación',
        'Lista_de_Pokémon_de_la_cuarta_generación',
        'Lista_de_Pokémon_de_la_quinta_generación',
        'Lista_de_Pokémon_de_la_sexta_generación']

gens = ['Lista_de_Pokémon_de_la_cuarta_generación']


# Set up the web driver options and service
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--disable-blink-features=AutomationControlled')
service = Service(ChromeDriverManager().install())


pokedex_url = './pokedex/'

# %%
def scrape_pokemon(driver, pkmn_name):
    # Connect to the website for the current Pokemon
    driver.get(base_url + pkmn_name)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    # Extract the Pokemon type information from the HTML
    pkmn_weight = soup.find("tr", attrs={"title": "Peso del Pokémon"}).td.text
    pkmn_weight = pkmn_weight.replace("kg", "").replace(",", ".").strip()

    mapAbilities = dict()

    # Find all the abilities of a Pokemon
    pkmn_abilities = soup.find("tr", attrs={"title": "Habilidades que puede conocer"}).td.findAll("a")

    # Find the hidden ability of a Pokemon
    ha_2 = soup.find("tr", attrs={"title": "Habilidad oculta"})
    is_ha = False

    if ha_2:
        ha_2 = ha_2.td.a.text
        is_ha = True

    # Print the abilities of a Pokemon
    map_abilities = {}
    for idx, ab in enumerate(pkmn_abilities):
        if len(ab.text) > 1:
            map_abilities[idx] = ab.text

    if is_ha:
        map_abilities['ha'] = ha_2
    
    
    # Extract the Pokemon ability information from the HTML
    pkmn_abilities = soup.select('tr[title^="Habilidades que puede conocer"] td a')
    ha_2 = soup.select_one('tr[title="Habilidad oculta"] td a').text if soup.select_one('tr[title="Habilidad oculta"]') else None
    num_abilities = len(pkmn_abilities) + (1 if ha_2 else 0)
    abilities = {idx: ab.text for idx, ab in enumerate(pkmn_abilities) if len(ab.text) > 1}
    if ha_2:
        abilities['ha'] = ha_2
    
    
    
    
    # Locate the table of stats (below an h2 with a specific id)
    pkmn_table_stats = soup.find("span", attrs={"id": "Caracter.C3.ADsticas_de_combate"}).parent.find_next('table')

    stats = {}
    stat_rows = pkmn_table_stats.find_all("tr")

    # Extract the stats from the table
    for idx, stat in enumerate(['hp', 'at', 'df', 'sa', 'sd', 'sp']):
        stats[stat] = int(stat_rows[idx+1].find_all("td")[0].text.strip())

    
    # Return a dictionary with the Pokemon information
    return {'weight': float(pkmn_weight), 'abilities': map_abilities, 'baseStats':stats}

# %%
# Define a function to save the list of dictionaries to a JSON file
def save_file(pokedex_url, gen, pkmn_list):
    with open(pokedex_url + gen + '.json', 'w', encoding="UTF-8") as fp:
        json.dump(pkmn_list, fp, indent=4, ensure_ascii=False)
        
        
def searchSprite(driver, soup, num_dex):
    return 'https://cdn.toast-studio.com/typedex/home/_' + str(num_dex) + '_regular.png'


# Set up the web driver and scrape data for each generation and Pokemon
with webdriver.Chrome(service=service, options=options) as driver:
    for gen in gens:
        numDexTemp = 0
        try:
            driver.get(base_url + gen)
            pkmn_soup = BeautifulSoup(driver.page_source, 'html.parser')
            
            #Removing rare things
            for s in pkmn_soup.select('sup'):
                s.extract()
                
            results = pkmn_soup.select('table.tabpokemon tbody tr')
            pkmn_list = []
            for result in results:
                fields = result.select('td')
                
                
                
                numDexRow = fields[0]
                if(numDexRow.has_attr('rowspan')):
                    numDexTemp = numDexRow.text.strip()
                
                
                if( len(fields) == 4):
                    numDexRow = numDexTemp
                    pkmn_dex_num = numDexTemp
                    imageRow = fields[0]
                    nameRow = fields[1]
                    typesRow = fields[2]
                    
                elif( len(fields) == 3):
                    numDexRow = numDexTemp
                    pkmn_dex_num = numDexTemp
                    imageRow = fields[0]
                    nameRow = fields[1]
                    
                elif( len(fields) == 2):
                    numDexRow = numDexTemp
                    pkmn_dex_num = numDexTemp
                    imageRow = fields[0]
                    typesRow = fields[1]
                    
                else:
                    imageRow = fields[1]
                    nameRow = fields[2]
                    typesRow = fields[3]
                    pkmn_dex_num = numDexRow.text.strip()
                
                pkmn_name = nameRow.select_one('a').get('title')
                print(f'{pkmn_dex_num}. {pkmn_name} ({gen})')
                
                pkmn_types = [a.get('title').replace('Tipo ', '') for a in typesRow.select('a')]
                tipo1 = pkmn_types[0]
                tipo2 = pkmn_types[1] if len(pkmn_types) > 1 else 'undefined'
                
                pkmn_sprite = searchSprite(driver, pkmn_soup, pkmn_dex_num)
                
                # Scrape the Pokemon data
                pkmn_data = scrape_pokemon(driver, pkmn_name)
                
                zeros = [0,0,0,0,0,0]
                level = 50
                
                # Create a new dictionary with the Pokemon data
                pkmn_dict = {'numDex': pkmn_dex_num, 'species': pkmn_name, 'type1': tipo1,
                             'type2': tipo2, 'ivs': zeros, 'evs': zeros, 'level': level,
                             'sprite': pkmn_sprite}
                pkmn_dict.update(pkmn_data)
                
                # Add the Pokemon dictionary to the pkmn_list
                pkmn_list.append(pkmn_dict)
                
                save_file(pokedex_url, gen, pkmn_list)
            print(f'Successfully saved data for {gen}.')
        except Exception as err:
            print(f'Error: {err}')

# Print a message indicating that the script has finished
print('Script finished.')
# Out:
# 0152. Chikorita (Lista_de_Pokémon_de_la_segunda_generación)
# 0153. Bayleef (Lista_de_Pokémon_de_la_segunda_generación)
# 0154. Meganium (Lista_de_Pokémon_de_la_segunda_generación)
# 0155. Cyndaquil (Lista_de_Pokémon_de_la_segunda_generación)
# 0156. Quilava (Lista_de_Pokémon_de_la_segunda_generación)
# 0157. Typhlosion (Lista_de_Pokémon_de_la_segunda_generación)
# 0157. Typhlosion de Hisui (Lista_de_Pokémon_de_la_segunda_generación)
# 0158. Totodile (Lista_de_Pokémon_de_la_segunda_generación)
# 0159. Croconaw (Lista_de_Pokémon_de_la_segunda_generación)
# 0160. Feraligatr (Lista_de_Pokémon_de_la_segunda_generación)
# 0161. Sentret (Lista_de_Pokémon_de_la_segunda_generación)
# 0162. Furret (Lista_de_Pokémon_de_la_segunda_generación)
# 0163. Hoothoot (Lista_de_Pokémon_de_la_segunda_generación)
# 0164. Noctowl (Lista_de_Pokémon_de_la_segunda_generación)
# 0165. Ledyba (Lista_de_Pokémon_de_la_segunda_generación)
# 0166. Ledian (Lista_de_Pokémon_de_la_segunda_generación)
# 0167. Spinarak (Lista_de_Pokémon_de_la_segunda_generación)
# 0168. Ariados (Lista_de_Pokémon_de_la_segunda_generación)
# 0169. Crobat (Lista_de_Pokémon_de_la_segunda_generación)
# 0170. Chinchou (Lista_de_Pokémon_de_la_segunda_generación)
# 0171. Lanturn (Lista_de_Pokémon_de_la_segunda_generación)
# 0172. Pichu (Lista_de_Pokémon_de_la_segunda_generación)
# 0173. Cleffa (Lista_de_Pokémon_de_la_segunda_generación)
# 0174. Igglybuff (Lista_de_Pokémon_de_la_segunda_generación)
# 0175. Togepi (Lista_de_Pokémon_de_la_segunda_generación)
# 0176. Togetic (Lista_de_Pokémon_de_la_segunda_generación)
# 0177. Natu (Lista_de_Pokémon_de_la_segunda_generación)
# 0178. Xatu (Lista_de_Pokémon_de_la_segunda_generación)
# 0179. Mareep (Lista_de_Pokémon_de_la_segunda_generación)
# 0180. Flaaffy (Lista_de_Pokémon_de_la_segunda_generación)
# 0181. Ampharos (Lista_de_Pokémon_de_la_segunda_generación)
# 0182. Bellossom (Lista_de_Pokémon_de_la_segunda_generación)
# 0183. Marill (Lista_de_Pokémon_de_la_segunda_generación)
# 0184. Azumarill (Lista_de_Pokémon_de_la_segunda_generación)
# 0185. Sudowoodo (Lista_de_Pokémon_de_la_segunda_generación)
# 0186. Politoed (Lista_de_Pokémon_de_la_segunda_generación)
# 0187. Hoppip (Lista_de_Pokémon_de_la_segunda_generación)
# 0188. Skiploom (Lista_de_Pokémon_de_la_segunda_generación)
# 0189. Jumpluff (Lista_de_Pokémon_de_la_segunda_generación)
# 0190. Aipom (Lista_de_Pokémon_de_la_segunda_generación)
# 0191. Sunkern (Lista_de_Pokémon_de_la_segunda_generación)
# 0192. Sunflora (Lista_de_Pokémon_de_la_segunda_generación)
# 0193. Yanma (Lista_de_Pokémon_de_la_segunda_generación)
# 0194. Wooper (Lista_de_Pokémon_de_la_segunda_generación)
# 0194. Wooper de Paldea (Lista_de_Pokémon_de_la_segunda_generación)
# 0195. Quagsire (Lista_de_Pokémon_de_la_segunda_generación)
# 0196. Espeon (Lista_de_Pokémon_de_la_segunda_generación)
# 0197. Umbreon (Lista_de_Pokémon_de_la_segunda_generación)
# 0198. Murkrow (Lista_de_Pokémon_de_la_segunda_generación)
# 0199. Slowking (Lista_de_Pokémon_de_la_segunda_generación)
# 0199. Slowking de Galar (Lista_de_Pokémon_de_la_segunda_generación)
# 0200. Misdreavus (Lista_de_Pokémon_de_la_segunda_generación)
# 0201. Unown (Lista_de_Pokémon_de_la_segunda_generación)
# 0202. Wobbuffet (Lista_de_Pokémon_de_la_segunda_generación)
# 0203. Girafarig (Lista_de_Pokémon_de_la_segunda_generación)
# 0204. Pineco (Lista_de_Pokémon_de_la_segunda_generación)
# 0205. Forretress (Lista_de_Pokémon_de_la_segunda_generación)
# 0206. Dunsparce (Lista_de_Pokémon_de_la_segunda_generación)
# 0207. Gligar (Lista_de_Pokémon_de_la_segunda_generación)
# 0208. Steelix (Lista_de_Pokémon_de_la_segunda_generación)
# 0209. Snubbull (Lista_de_Pokémon_de_la_segunda_generación)
# 0210. Granbull (Lista_de_Pokémon_de_la_segunda_generación)
# 0211. Qwilfish (Lista_de_Pokémon_de_la_segunda_generación)
# 0211. Qwilfish de Hisui (Lista_de_Pokémon_de_la_segunda_generación)
# 0212. Scizor (Lista_de_Pokémon_de_la_segunda_generación)
# 0213. Shuckle (Lista_de_Pokémon_de_la_segunda_generación)
# 0214. Heracross (Lista_de_Pokémon_de_la_segunda_generación)
# 0215. Sneasel (Lista_de_Pokémon_de_la_segunda_generación)
# 0215. Sneasel de Hisui (Lista_de_Pokémon_de_la_segunda_generación)
# 0216. Teddiursa (Lista_de_Pokémon_de_la_segunda_generación)
# 0217. Ursaring (Lista_de_Pokémon_de_la_segunda_generación)
# 0218. Slugma (Lista_de_Pokémon_de_la_segunda_generación)
# 0219. Magcargo (Lista_de_Pokémon_de_la_segunda_generación)
# 0220. Swinub (Lista_de_Pokémon_de_la_segunda_generación)
# 0221. Piloswine (Lista_de_Pokémon_de_la_segunda_generación)
# 0222. Corsola (Lista_de_Pokémon_de_la_segunda_generación)
# 0222. Corsola de Galar (Lista_de_Pokémon_de_la_segunda_generación)
# 0223. Remoraid (Lista_de_Pokémon_de_la_segunda_generación)
# 0224. Octillery (Lista_de_Pokémon_de_la_segunda_generación)
# 0225. Delibird (Lista_de_Pokémon_de_la_segunda_generación)
# 0226. Mantine (Lista_de_Pokémon_de_la_segunda_generación)
# 0227. Skarmory (Lista_de_Pokémon_de_la_segunda_generación)
# 0228. Houndour (Lista_de_Pokémon_de_la_segunda_generación)
# 0229. Houndoom (Lista_de_Pokémon_de_la_segunda_generación)
# 0230. Kingdra (Lista_de_Pokémon_de_la_segunda_generación)
# 0231. Phanpy (Lista_de_Pokémon_de_la_segunda_generación)
# 0232. Donphan (Lista_de_Pokémon_de_la_segunda_generación)
# 0233. Porygon2 (Lista_de_Pokémon_de_la_segunda_generación)
# 0234. Stantler (Lista_de_Pokémon_de_la_segunda_generación)
# 0235. Smeargle (Lista_de_Pokémon_de_la_segunda_generación)
# 0236. Tyrogue (Lista_de_Pokémon_de_la_segunda_generación)
# 0237. Hitmontop (Lista_de_Pokémon_de_la_segunda_generación)
# 0238. Smoochum (Lista_de_Pokémon_de_la_segunda_generación)
# 0239. Elekid (Lista_de_Pokémon_de_la_segunda_generación)
# 0240. Magby (Lista_de_Pokémon_de_la_segunda_generación)
# 0241. Miltank (Lista_de_Pokémon_de_la_segunda_generación)
# 0242. Blissey (Lista_de_Pokémon_de_la_segunda_generación)
# 0243. Raikou (Lista_de_Pokémon_de_la_segunda_generación)
# 0244. Entei (Lista_de_Pokémon_de_la_segunda_generación)
# 0245. Suicune (Lista_de_Pokémon_de_la_segunda_generación)
# 0246. Larvitar (Lista_de_Pokémon_de_la_segunda_generación)
# 0247. Pupitar (Lista_de_Pokémon_de_la_segunda_generación)
# 0248. Tyranitar (Lista_de_Pokémon_de_la_segunda_generación)
# 0249. Lugia (Lista_de_Pokémon_de_la_segunda_generación)
# 0250. Ho-Oh (Lista_de_Pokémon_de_la_segunda_generación)
# 0251. Celebi (Lista_de_Pokémon_de_la_segunda_generación)
# Successfully saved data for Lista_de_Pokémon_de_la_segunda_generación.
# 0252. Treecko (Lista_de_Pokémon_de_la_tercera_generación)
# 0253. Grovyle (Lista_de_Pokémon_de_la_tercera_generación)
# 0254. Sceptile (Lista_de_Pokémon_de_la_tercera_generación)
# 0255. Torchic (Lista_de_Pokémon_de_la_tercera_generación)
# 0256. Combusken (Lista_de_Pokémon_de_la_tercera_generación)
# 0257. Blaziken (Lista_de_Pokémon_de_la_tercera_generación)
# 0258. Mudkip (Lista_de_Pokémon_de_la_tercera_generación)
# 0259. Marshtomp (Lista_de_Pokémon_de_la_tercera_generación)
# 0260. Swampert (Lista_de_Pokémon_de_la_tercera_generación)
# 0261. Poochyena (Lista_de_Pokémon_de_la_tercera_generación)
# 0262. Mightyena (Lista_de_Pokémon_de_la_tercera_generación)
# 0263. Zigzagoon (Lista_de_Pokémon_de_la_tercera_generación)
# 0263. Zigzagoon de Galar (Lista_de_Pokémon_de_la_tercera_generación)
# 0264. Linoone (Lista_de_Pokémon_de_la_tercera_generación)
# 0264. Linoone de Galar (Lista_de_Pokémon_de_la_tercera_generación)
# 0265. Wurmple (Lista_de_Pokémon_de_la_tercera_generación)
# 0266. Silcoon (Lista_de_Pokémon_de_la_tercera_generación)
# 0267. Beautifly (Lista_de_Pokémon_de_la_tercera_generación)
# 0268. Cascoon (Lista_de_Pokémon_de_la_tercera_generación)
# 0269. Dustox (Lista_de_Pokémon_de_la_tercera_generación)
# 0270. Lotad (Lista_de_Pokémon_de_la_tercera_generación)
# 0271. Lombre (Lista_de_Pokémon_de_la_tercera_generación)
# 0272. Ludicolo (Lista_de_Pokémon_de_la_tercera_generación)
# 0273. Seedot (Lista_de_Pokémon_de_la_tercera_generación)
# 0274. Nuzleaf (Lista_de_Pokémon_de_la_tercera_generación)
# 0275. Shiftry (Lista_de_Pokémon_de_la_tercera_generación)
# 0276. Taillow (Lista_de_Pokémon_de_la_tercera_generación)
# 0277. Swellow (Lista_de_Pokémon_de_la_tercera_generación)
# 0278. Wingull (Lista_de_Pokémon_de_la_tercera_generación)
# 0279. Pelipper (Lista_de_Pokémon_de_la_tercera_generación)
# 0280. Ralts (Lista_de_Pokémon_de_la_tercera_generación)
# 0281. Kirlia (Lista_de_Pokémon_de_la_tercera_generación)
# 0282. Gardevoir (Lista_de_Pokémon_de_la_tercera_generación)
# 0283. Surskit (Lista_de_Pokémon_de_la_tercera_generación)
# 0284. Masquerain (Lista_de_Pokémon_de_la_tercera_generación)
# 0285. Shroomish (Lista_de_Pokémon_de_la_tercera_generación)
# 0286. Breloom (Lista_de_Pokémon_de_la_tercera_generación)
# 0287. Slakoth (Lista_de_Pokémon_de_la_tercera_generación)
# 0288. Vigoroth (Lista_de_Pokémon_de_la_tercera_generación)
# 0289. Slaking (Lista_de_Pokémon_de_la_tercera_generación)
# 0290. Nincada (Lista_de_Pokémon_de_la_tercera_generación)
# 0291. Ninjask (Lista_de_Pokémon_de_la_tercera_generación)
# 0292. Shedinja (Lista_de_Pokémon_de_la_tercera_generación)
# 0293. Whismur (Lista_de_Pokémon_de_la_tercera_generación)
# 0294. Loudred (Lista_de_Pokémon_de_la_tercera_generación)
# 0295. Exploud (Lista_de_Pokémon_de_la_tercera_generación)
# 0296. Makuhita (Lista_de_Pokémon_de_la_tercera_generación)
# 0297. Hariyama (Lista_de_Pokémon_de_la_tercera_generación)
# 0298. Azurill (Lista_de_Pokémon_de_la_tercera_generación)
# 0299. Nosepass (Lista_de_Pokémon_de_la_tercera_generación)
# 0300. Skitty (Lista_de_Pokémon_de_la_tercera_generación)
# 0301. Delcatty (Lista_de_Pokémon_de_la_tercera_generación)
# 0302. Sableye (Lista_de_Pokémon_de_la_tercera_generación)
# 0303. Mawile (Lista_de_Pokémon_de_la_tercera_generación)
# 0304. Aron (Lista_de_Pokémon_de_la_tercera_generación)
# 0305. Lairon (Lista_de_Pokémon_de_la_tercera_generación)
# 0306. Aggron (Lista_de_Pokémon_de_la_tercera_generación)
# 0307. Meditite (Lista_de_Pokémon_de_la_tercera_generación)
# 0308. Medicham (Lista_de_Pokémon_de_la_tercera_generación)
# 0309. Electrike (Lista_de_Pokémon_de_la_tercera_generación)
# 0310. Manectric (Lista_de_Pokémon_de_la_tercera_generación)
# 0311. Plusle (Lista_de_Pokémon_de_la_tercera_generación)
# 0312. Minun (Lista_de_Pokémon_de_la_tercera_generación)
# 0313. Volbeat (Lista_de_Pokémon_de_la_tercera_generación)
# 0314. Illumise (Lista_de_Pokémon_de_la_tercera_generación)
# 0315. Roselia (Lista_de_Pokémon_de_la_tercera_generación)
# 0316. Gulpin (Lista_de_Pokémon_de_la_tercera_generación)
# 0317. Swalot (Lista_de_Pokémon_de_la_tercera_generación)
# 0318. Carvanha (Lista_de_Pokémon_de_la_tercera_generación)
# 0319. Sharpedo (Lista_de_Pokémon_de_la_tercera_generación)
# 0320. Wailmer (Lista_de_Pokémon_de_la_tercera_generación)
# 0321. Wailord (Lista_de_Pokémon_de_la_tercera_generación)
# 0322. Numel (Lista_de_Pokémon_de_la_tercera_generación)
# 0323. Camerupt (Lista_de_Pokémon_de_la_tercera_generación)
# 0324. Torkoal (Lista_de_Pokémon_de_la_tercera_generación)
# 0325. Spoink (Lista_de_Pokémon_de_la_tercera_generación)
# 0326. Grumpig (Lista_de_Pokémon_de_la_tercera_generación)
# 0327. Spinda (Lista_de_Pokémon_de_la_tercera_generación)
# 0328. Trapinch (Lista_de_Pokémon_de_la_tercera_generación)
# 0329. Vibrava (Lista_de_Pokémon_de_la_tercera_generación)
# 0330. Flygon (Lista_de_Pokémon_de_la_tercera_generación)
# 0331. Cacnea (Lista_de_Pokémon_de_la_tercera_generación)
# 0332. Cacturne (Lista_de_Pokémon_de_la_tercera_generación)
# 0333. Swablu (Lista_de_Pokémon_de_la_tercera_generación)
# 0334. Altaria (Lista_de_Pokémon_de_la_tercera_generación)
# 0335. Zangoose (Lista_de_Pokémon_de_la_tercera_generación)
# 0336. Seviper (Lista_de_Pokémon_de_la_tercera_generación)
# 0337. Lunatone (Lista_de_Pokémon_de_la_tercera_generación)
# 0338. Solrock (Lista_de_Pokémon_de_la_tercera_generación)
# 0339. Barboach (Lista_de_Pokémon_de_la_tercera_generación)
# 0340. Whiscash (Lista_de_Pokémon_de_la_tercera_generación)
# 0341. Corphish (Lista_de_Pokémon_de_la_tercera_generación)
# 0342. Crawdaunt (Lista_de_Pokémon_de_la_tercera_generación)
# 0343. Baltoy (Lista_de_Pokémon_de_la_tercera_generación)
# 0344. Claydol (Lista_de_Pokémon_de_la_tercera_generación)
# 0345. Lileep (Lista_de_Pokémon_de_la_tercera_generación)
# 0346. Cradily (Lista_de_Pokémon_de_la_tercera_generación)
# 0347. Anorith (Lista_de_Pokémon_de_la_tercera_generación)
# 0348. Armaldo (Lista_de_Pokémon_de_la_tercera_generación)
# 0349. Feebas (Lista_de_Pokémon_de_la_tercera_generación)
# 0350. Milotic (Lista_de_Pokémon_de_la_tercera_generación)
# 0351. Castform (Lista_de_Pokémon_de_la_tercera_generación)
# 0351. Castform (Lista_de_Pokémon_de_la_tercera_generación)
# 0351. Castform (Lista_de_Pokémon_de_la_tercera_generación)
# 0351. Castform (Lista_de_Pokémon_de_la_tercera_generación)
# 0352. Kecleon (Lista_de_Pokémon_de_la_tercera_generación)
# 0353. Shuppet (Lista_de_Pokémon_de_la_tercera_generación)
# 0354. Banette (Lista_de_Pokémon_de_la_tercera_generación)
# 0355. Duskull (Lista_de_Pokémon_de_la_tercera_generación)
# 0356. Dusclops (Lista_de_Pokémon_de_la_tercera_generación)
# 0357. Tropius (Lista_de_Pokémon_de_la_tercera_generación)
# 0358. Chimecho (Lista_de_Pokémon_de_la_tercera_generación)
# 0359. Absol (Lista_de_Pokémon_de_la_tercera_generación)
# 0360. Wynaut (Lista_de_Pokémon_de_la_tercera_generación)
# 0361. Snorunt (Lista_de_Pokémon_de_la_tercera_generación)
# 0362. Glalie (Lista_de_Pokémon_de_la_tercera_generación)
# 0363. Spheal (Lista_de_Pokémon_de_la_tercera_generación)
# 0364. Sealeo (Lista_de_Pokémon_de_la_tercera_generación)
# 0365. Walrein (Lista_de_Pokémon_de_la_tercera_generación)
# 0366. Clamperl (Lista_de_Pokémon_de_la_tercera_generación)
# 0367. Huntail (Lista_de_Pokémon_de_la_tercera_generación)
# 0368. Gorebyss (Lista_de_Pokémon_de_la_tercera_generación)
# 0369. Relicanth (Lista_de_Pokémon_de_la_tercera_generación)
# 0370. Luvdisc (Lista_de_Pokémon_de_la_tercera_generación)
# 0371. Bagon (Lista_de_Pokémon_de_la_tercera_generación)
# 0372. Shelgon (Lista_de_Pokémon_de_la_tercera_generación)
# 0373. Salamence (Lista_de_Pokémon_de_la_tercera_generación)
# 0374. Beldum (Lista_de_Pokémon_de_la_tercera_generación)
# 0375. Metang (Lista_de_Pokémon_de_la_tercera_generación)
# 0376. Metagross (Lista_de_Pokémon_de_la_tercera_generación)
# 0377. Regirock (Lista_de_Pokémon_de_la_tercera_generación)
# 0378. Regice (Lista_de_Pokémon_de_la_tercera_generación)
# 0379. Registeel (Lista_de_Pokémon_de_la_tercera_generación)
# 0380. Latias (Lista_de_Pokémon_de_la_tercera_generación)
# 0381. Latios (Lista_de_Pokémon_de_la_tercera_generación)
# 0382. Kyogre (Lista_de_Pokémon_de_la_tercera_generación)
# 0383. Groudon (Lista_de_Pokémon_de_la_tercera_generación)
# 0384. Rayquaza (Lista_de_Pokémon_de_la_tercera_generación)
# 0385. Jirachi (Lista_de_Pokémon_de_la_tercera_generación)
# 0386. Deoxys (Lista_de_Pokémon_de_la_tercera_generación)
# Successfully saved data for Lista_de_Pokémon_de_la_tercera_generación.
# 0387. Turtwig (Lista_de_Pokémon_de_la_cuarta_generación)
# 0388. Grotle (Lista_de_Pokémon_de_la_cuarta_generación)
# 0389. Torterra (Lista_de_Pokémon_de_la_cuarta_generación)
# 0390. Chimchar (Lista_de_Pokémon_de_la_cuarta_generación)
# 0391. Monferno (Lista_de_Pokémon_de_la_cuarta_generación)
# 0392. Infernape (Lista_de_Pokémon_de_la_cuarta_generación)
# 0393. Piplup (Lista_de_Pokémon_de_la_cuarta_generación)
# 0394. Prinplup (Lista_de_Pokémon_de_la_cuarta_generación)
# 0395. Empoleon (Lista_de_Pokémon_de_la_cuarta_generación)
# 0396. Starly (Lista_de_Pokémon_de_la_cuarta_generación)
# 0397. Staravia (Lista_de_Pokémon_de_la_cuarta_generación)
# 0398. Staraptor (Lista_de_Pokémon_de_la_cuarta_generación)
# 0399. Bidoof (Lista_de_Pokémon_de_la_cuarta_generación)
# 0400. Bibarel (Lista_de_Pokémon_de_la_cuarta_generación)
# 0401. Kricketot (Lista_de_Pokémon_de_la_cuarta_generación)
# 0402. Kricketune (Lista_de_Pokémon_de_la_cuarta_generación)
# 0403. Shinx (Lista_de_Pokémon_de_la_cuarta_generación)
# 0404. Luxio (Lista_de_Pokémon_de_la_cuarta_generación)
# 0405. Luxray (Lista_de_Pokémon_de_la_cuarta_generación)
# 0406. Budew (Lista_de_Pokémon_de_la_cuarta_generación)
# 0407. Roserade (Lista_de_Pokémon_de_la_cuarta_generación)
# 0408. Cranidos (Lista_de_Pokémon_de_la_cuarta_generación)
# 0409. Rampardos (Lista_de_Pokémon_de_la_cuarta_generación)
# 0410. Shieldon (Lista_de_Pokémon_de_la_cuarta_generación)
# 0411. Bastiodon (Lista_de_Pokémon_de_la_cuarta_generación)
# 0412. Burmy (Lista_de_Pokémon_de_la_cuarta_generación)
# 0413. Wormadam (Lista_de_Pokémon_de_la_cuarta_generación)
# 0413. Wormadam (Lista_de_Pokémon_de_la_cuarta_generación)
# 0413. Wormadam (Lista_de_Pokémon_de_la_cuarta_generación)
# 0414. Mothim (Lista_de_Pokémon_de_la_cuarta_generación)
# 0415. Combee (Lista_de_Pokémon_de_la_cuarta_generación)
# 0416. Vespiquen (Lista_de_Pokémon_de_la_cuarta_generación)
# 0417. Pachirisu (Lista_de_Pokémon_de_la_cuarta_generación)
# 0418. Buizel (Lista_de_Pokémon_de_la_cuarta_generación)
# 0419. Floatzel (Lista_de_Pokémon_de_la_cuarta_generación)
# 0420. Cherubi (Lista_de_Pokémon_de_la_cuarta_generación)
# 0421. Cherrim (Lista_de_Pokémon_de_la_cuarta_generación)
# 0422. Shellos (Lista_de_Pokémon_de_la_cuarta_generación)
# 0423. Gastrodon (Lista_de_Pokémon_de_la_cuarta_generación)
# 0424. Ambipom (Lista_de_Pokémon_de_la_cuarta_generación)
# 0425. Drifloon (Lista_de_Pokémon_de_la_cuarta_generación)
# 0426. Drifblim (Lista_de_Pokémon_de_la_cuarta_generación)
# 0427. Buneary (Lista_de_Pokémon_de_la_cuarta_generación)
# 0428. Lopunny (Lista_de_Pokémon_de_la_cuarta_generación)
# 0429. Mismagius (Lista_de_Pokémon_de_la_cuarta_generación)
# 0430. Honchkrow (Lista_de_Pokémon_de_la_cuarta_generación)
# 0431. Glameow (Lista_de_Pokémon_de_la_cuarta_generación)
# 0432. Purugly (Lista_de_Pokémon_de_la_cuarta_generación)
# 0433. Chingling (Lista_de_Pokémon_de_la_cuarta_generación)
# 0434. Stunky (Lista_de_Pokémon_de_la_cuarta_generación)
# 0435. Skuntank (Lista_de_Pokémon_de_la_cuarta_generación)
# 0436. Bronzor (Lista_de_Pokémon_de_la_cuarta_generación)
# 0437. Bronzong (Lista_de_Pokémon_de_la_cuarta_generación)
# 0438. Bonsly (Lista_de_Pokémon_de_la_cuarta_generación)
# 0439. Mime Jr. (Lista_de_Pokémon_de_la_cuarta_generación)
# 0440. Happiny (Lista_de_Pokémon_de_la_cuarta_generación)
# 0441. Chatot (Lista_de_Pokémon_de_la_cuarta_generación)
# 0442. Spiritomb (Lista_de_Pokémon_de_la_cuarta_generación)
# 0443. Gible (Lista_de_Pokémon_de_la_cuarta_generación)
# 0444. Gabite (Lista_de_Pokémon_de_la_cuarta_generación)
# 0445. Garchomp (Lista_de_Pokémon_de_la_cuarta_generación)
# 0446. Munchlax (Lista_de_Pokémon_de_la_cuarta_generación)
# 0447. Riolu (Lista_de_Pokémon_de_la_cuarta_generación)
# 0448. Lucario (Lista_de_Pokémon_de_la_cuarta_generación)
# 0449. Hippopotas (Lista_de_Pokémon_de_la_cuarta_generación)
# 0450. Hippowdon (Lista_de_Pokémon_de_la_cuarta_generación)
# 0451. Skorupi (Lista_de_Pokémon_de_la_cuarta_generación)
# 0452. Drapion (Lista_de_Pokémon_de_la_cuarta_generación)
# 0453. Croagunk (Lista_de_Pokémon_de_la_cuarta_generación)
# 0454. Toxicroak (Lista_de_Pokémon_de_la_cuarta_generación)
# 0455. Carnivine (Lista_de_Pokémon_de_la_cuarta_generación)
# 0456. Finneon (Lista_de_Pokémon_de_la_cuarta_generación)
# 0457. Lumineon (Lista_de_Pokémon_de_la_cuarta_generación)
# 0458. Mantyke (Lista_de_Pokémon_de_la_cuarta_generación)
# 0459. Snover (Lista_de_Pokémon_de_la_cuarta_generación)
# 0460. Abomasnow (Lista_de_Pokémon_de_la_cuarta_generación)
# 0461. Weavile (Lista_de_Pokémon_de_la_cuarta_generación)
# 0462. Magnezone (Lista_de_Pokémon_de_la_cuarta_generación)
# 0463. Lickilicky (Lista_de_Pokémon_de_la_cuarta_generación)
# 0464. Rhyperior (Lista_de_Pokémon_de_la_cuarta_generación)
# 0465. Tangrowth (Lista_de_Pokémon_de_la_cuarta_generación)
# 0466. Electivire (Lista_de_Pokémon_de_la_cuarta_generación)
# 0467. Magmortar (Lista_de_Pokémon_de_la_cuarta_generación)
# 0468. Togekiss (Lista_de_Pokémon_de_la_cuarta_generación)
# 0469. Yanmega (Lista_de_Pokémon_de_la_cuarta_generación)
# 0470. Leafeon (Lista_de_Pokémon_de_la_cuarta_generación)
# 0471. Glaceon (Lista_de_Pokémon_de_la_cuarta_generación)
# 0472. Gliscor (Lista_de_Pokémon_de_la_cuarta_generación)
# 0473. Mamoswine (Lista_de_Pokémon_de_la_cuarta_generación)
# 0474. Porygon-Z (Lista_de_Pokémon_de_la_cuarta_generación)
# 0475. Gallade (Lista_de_Pokémon_de_la_cuarta_generación)
# 0476. Probopass (Lista_de_Pokémon_de_la_cuarta_generación)
# 0477. Dusknoir (Lista_de_Pokémon_de_la_cuarta_generación)
# 0478. Froslass (Lista_de_Pokémon_de_la_cuarta_generación)
# 0479. Rotom (Lista_de_Pokémon_de_la_cuarta_generación)
# 0479. Rotom (Lista_de_Pokémon_de_la_cuarta_generación)
# 0479. Rotom (Lista_de_Pokémon_de_la_cuarta_generación)
# 0479. Rotom (Lista_de_Pokémon_de_la_cuarta_generación)
# 0479. Rotom (Lista_de_Pokémon_de_la_cuarta_generación)
# 0479. Rotom (Lista_de_Pokémon_de_la_cuarta_generación)
# 0480. Uxie (Lista_de_Pokémon_de_la_cuarta_generación)
# 0481. Mesprit (Lista_de_Pokémon_de_la_cuarta_generación)
# 0482. Azelf (Lista_de_Pokémon_de_la_cuarta_generación)
# 0483. Dialga (Lista_de_Pokémon_de_la_cuarta_generación)
# Error: could not convert string to float: '683.0 D850.0 FO'
# Script finished.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
